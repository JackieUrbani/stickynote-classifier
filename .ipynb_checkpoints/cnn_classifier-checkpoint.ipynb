# %%
# Limit GPU ram usage for multiple models
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)

    except RuntimeError as e:
        print(e)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import keras
from keras.models import Sequential
from keras.models import model_from_json
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import np_utils
from keras import layers
from keras import optimizers

from sklearn.metrics import classification_report,confusion_matrix
from sklearn.model_selection import train_test_split

import cv2
import os

import numpy as np

# %%
labels = ['throwaway', 'arrow', 'M', 'S', 'F']

def get_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                # Read in and set to grayscale
                img_arr = cv2.cvtColor(cv2.imread(os.path.join(path, img)), cv2.COLOR_BGR2GRAY)
                data.append([img_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)

# %%
data = get_data('processed-images')
# Out:
# <ipython-input-3-7501c9d52376>:15: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return np.array(data)

# %%
l = []
for i in data:
    if(i[1] == 0):
        l.append(labels[0])
    elif(i[1] == 1):
        l.append(labels[1])
    elif(i[1] == 2):
        l.append(labels[2])
    elif(i[1] == 3):
        l.append(labels[3])
    else:
        l.append(labels[4])
sns.set_style('darkgrid')
sns.countplot(l)
# Out:
# C:\Users\johna\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:ylabel='count'>

# %%
plt.figure(figsize = (5,5))
plt.imshow(data[500][0])
plt.title(labels[data[500][1]])
# Out:
# Text(0.5, 1.0, 'F')

# %%
# Split into a training and validation set
X = []
y = []

for feature, label in data:
  X.append(feature)
  y.append(label)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
# Normalize the data
X_train = np.array(X_train) / 255
X_test = np.array(X_test) / 255
X_train = X_train.reshape(X_train.shape[0], 128,128,1)
X_test = X_test.reshape(X_test.shape[0], 128,128,1)
y_train = np.array(y_train)
y_test = np.array(y_test)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (365, 128, 128, 1)
# (365,)
# (157, 128, 128, 1)
# (157,)

# %%
# One-hot encoding
print("Shape before one-hot encoding: ", y_train.shape)
y_train = np_utils.to_categorical(y_train, len(labels))
y_test = np_utils.to_categorical(y_test, len(labels))
print("Shape after one-hot encoding: ", y_train.shape)
# Out:
# Shape before one-hot encoding:  (365,)
# Shape after one-hot encoding:  (365, 5)

# %%
from tensorflow.keras.callbacks import LearningRateScheduler

model = Sequential()

model.add(layers.Conv2D(128, (12, 12), activation='relu', strides=(2,2), padding='valid', input_shape=(128, 128, 1)))
model.add(layers.Conv2D(256, (5, 5), activation='relu', strides=(1,2), padding='same'))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Flatten())
model.add(layers.Dense(1024, activation='relu'))
model.add(layers.Dense(len(labels)))

model.compile(optimizers.Adam(learning_rate=0.0001, beta_1=0.95),
              loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 59, 59, 128)       18560
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 59, 30, 256)       819456
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 29, 15, 256)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 111360)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              114033664
# _________________________________________________________________
# dense_3 (Dense)              (None, 5)                 5125
# =================================================================
# Total params: 114,876,805
# Trainable params: 114,876,805
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, epochs=15, batch_size=64, validation_data=(X_test, y_test))
# Out:
# Epoch 1/15
# 6/6 [==============================] - 4s 348ms/step - loss: 1.7563 - accuracy: 0.2378 - val_loss: 1.5742 - val_accuracy: 0.5669
# Epoch 2/15
# 6/6 [==============================] - 1s 121ms/step - loss: 1.5614 - accuracy: 0.4390 - val_loss: 1.5928 - val_accuracy: 0.2803
# Epoch 3/15
# 6/6 [==============================] - 1s 121ms/step - loss: 1.5061 - accuracy: 0.3561 - val_loss: 1.5345 - val_accuracy: 0.4841
# Epoch 4/15
# 6/6 [==============================] - 1s 120ms/step - loss: 1.4966 - accuracy: 0.4498 - val_loss: 1.5003 - val_accuracy: 0.2803
# Epoch 5/15
# 6/6 [==============================] - 1s 120ms/step - loss: 1.4551 - accuracy: 0.3544 - val_loss: 1.4377 - val_accuracy: 0.2803
# Epoch 6/15
# 6/6 [==============================] - 1s 120ms/step - loss: 1.3528 - accuracy: 0.3479 - val_loss: 1.3328 - val_accuracy: 0.8217
# Epoch 7/15
# 6/6 [==============================] - 1s 119ms/step - loss: 1.2584 - accuracy: 0.7868 - val_loss: 1.2198 - val_accuracy: 0.7325
# Epoch 8/15
# 6/6 [==============================] - 1s 120ms/step - loss: 1.1192 - accuracy: 0.8307 - val_loss: 1.0747 - val_accuracy: 0.7898
# Epoch 9/15
# 6/6 [==============================] - 1s 121ms/step - loss: 0.9622 - accuracy: 0.8008 - val_loss: 0.9057 - val_accuracy: 0.8599
# Epoch 10/15
# 6/6 [==============================] - 1s 120ms/step - loss: 0.7751 - accuracy: 0.8737 - val_loss: 0.7150 - val_accuracy: 0.8790
# Epoch 11/15
# 6/6 [==============================] - 1s 120ms/step - loss: 0.5921 - accuracy: 0.8915 - val_loss: 0.5527 - val_accuracy: 0.9172
# Epoch 12/15
# 6/6 [==============================] - 1s 120ms/step - loss: 0.4387 - accuracy: 0.9356 - val_loss: 0.4027 - val_accuracy: 0.9682
# Epoch 13/15
# 6/6 [==============================] - 1s 121ms/step - loss: 0.3181 - accuracy: 0.9700 - val_loss: 0.3004 - val_accuracy: 0.9809
# Epoch 14/15
# 6/6 [==============================] - 1s 120ms/step - loss: 0.2184 - accuracy: 0.9811 - val_loss: 0.1979 - val_accuracy: 1.0000
# Epoch 15/15
# 6/6 [==============================] - 1s 119ms/step - loss: 0.1601 - accuracy: 0.9908 - val_loss: 0.1380 - val_accuracy: 1.0000

# %%
plt.plot(history.history['accuracy'], label = 'accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')

test_loss, test_acc = model.evaluate(X_test,  y_test, verbose=2)

print(test_acc)
# Out:
# 5/5 - 0s - loss: 0.1380 - accuracy: 1.0000
# 1.0

# %%
def predict(filename):
    testing_img = cv2.cvtColor(cv2.imread(filename), cv2.COLOR_BGR2GRAY)
    testing_img = np.array(testing_img) / 255
    testing_img = testing_img.reshape(1,128,128,1)

    prediction = model.predict(testing_img)
    print(prediction)
    
    i = 0
    max_val_i = 0
    max_val = prediction[0,0]
    for label in prediction[0]:
        if label > max_val:
            max_val_i = i
            max_val = label
        i = i + 1
    
    return labels[max_val_i]

# %%
predict('testing5.png')
# Out:
# [[ 0.7191403   3.6961954  -0.71862173 -0.1750281  -0.45400414]]
# 'arrow'

# %%
# Serialize successful model to JSON
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
    
# Serialize weights to HDF5
model.save_weights("model.h5")
print("Saved model to disk")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-2cf9d6f0f325> in <module>
#       1 # Serialize successful model to JSON
#       2 with open("model.json", "w") as json_file:
# ----> 3     json_file.write(model_from_json.model_json)
#       4
#       5 # Serialize weights to HDF5
#
# AttributeError: 'function' object has no attribute 'model_json'
