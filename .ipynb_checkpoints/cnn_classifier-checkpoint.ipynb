# %%
# Limit GPU ram usage for multiple models
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)

    except RuntimeError as e:
        print(e)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import keras
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import np_utils
from keras import layers
from keras import optimizers

from sklearn.metrics import classification_report,confusion_matrix
from sklearn.model_selection import train_test_split

import cv2
import os

import numpy as np

# %%
labels = ['up_arrow', 'left_arrow', 'down_arrow', 'right_arrow']

def get_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                # Read in and set to grayscale
                img_arr = cv2.cvtColor(cv2.imread(os.path.join(path, img)), cv2.COLOR_BGR2GRAY)
                data.append([img_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)

# %%
data = get_data('processed-images')
# Out:
# <ipython-input-3-0ade627b99dc>:15: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return np.array(data)

# %%
l = []
for i in data:
    if(i[1] == 0):
        l.append(labels[0])
    elif(i[1] == 1):
        l.append(labels[1])
    elif(i[1] == 2):
        l.append(labels[2])
    else:
        l.append(labels[3])
sns.set_style('darkgrid')
sns.countplot(l)
# Out:
# C:\Users\johna\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:ylabel='count'>

# %%
plt.figure(figsize = (5,5))
plt.imshow(data[1][0])
plt.title(labels[data[0][1]])
# Out:
# Text(0.5, 1.0, 'up_arrow')

# %%
# Split into a training and validation set
X = []
y = []

for feature, label in data:
  X.append(feature)
  y.append(label)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
# Normalize the data
X_train = np.array(X_train) / 255
X_test = np.array(X_test) / 255
X_train = X_train.reshape(X_train.shape[0], 128,128,1)
X_test = X_test.reshape(X_test.shape[0], 128,128,1)
y_train = np.array(y_train)
y_test = np.array(y_test)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (128, 128, 128, 1)
# (128,)
# (32, 128, 128, 1)
# (32,)

# %%
# TODO:
# Make images much more clear, sharpen center symbol and attempt to make background completely blank

# %%
# One-hot encoding
print("Shape before one-hot encoding: ", y_train.shape)
y_train = np_utils.to_categorical(y_train, len(labels))
y_test = np_utils.to_categorical(y_test, len(labels))
print("Shape after one-hot encoding: ", y_train.shape)
# Out:
# Shape before one-hot encoding:  (128,)
# Shape after one-hot encoding:  (128, 4)

# %%
from tensorflow.keras.callbacks import LearningRateScheduler

model = Sequential()

model.add(layers.Conv2D(128, (12, 12), activation='relu', strides=(2,2), padding='valid', input_shape=(128, 128, 1)))
model.add(layers.Conv2D(256, (5, 5), activation='relu', strides=(1,2), padding='same'))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Flatten())
model.add(layers.Dense(1024, activation='relu'))
model.add(layers.Dense(len(labels)))

model.compile(optimizers.Adam(learning_rate=0.0004, beta_1=0.95),
              loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_22 (Conv2D)           (None, 59, 59, 128)       18560
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 59, 30, 256)       819456
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 29, 15, 256)       0
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 111360)            0
# _________________________________________________________________
# dense_22 (Dense)             (None, 1024)              114033664
# _________________________________________________________________
# dense_23 (Dense)             (None, 4)                 4100
# =================================================================
# Total params: 114,875,780
# Trainable params: 114,875,780
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, epochs=20, batch_size=16, validation_data=(X_test, y_test))
# Out:
# Epoch 1/20
# 8/8 [==============================] - 1s 79ms/step - loss: 4.5502 - accuracy: 0.2062 - val_loss: 1.3862 - val_accuracy: 0.1250
# Epoch 2/20
# 8/8 [==============================] - 0s 54ms/step - loss: 1.3945 - accuracy: 0.2917 - val_loss: 1.3807 - val_accuracy: 0.2500
# Epoch 3/20
# 8/8 [==============================] - 0s 53ms/step - loss: 1.3798 - accuracy: 0.2216 - val_loss: 1.4055 - val_accuracy: 0.2500
# Epoch 4/20
# 8/8 [==============================] - 0s 53ms/step - loss: 1.3691 - accuracy: 0.3121 - val_loss: 1.3783 - val_accuracy: 0.3125
# Epoch 5/20
# 8/8 [==============================] - 0s 53ms/step - loss: 1.3575 - accuracy: 0.4327 - val_loss: 1.3965 - val_accuracy: 0.1875
# Epoch 6/20
# 8/8 [==============================] - 0s 53ms/step - loss: 1.3700 - accuracy: 0.4281 - val_loss: 1.3311 - val_accuracy: 0.7188
# Epoch 7/20
# 8/8 [==============================] - 0s 53ms/step - loss: 1.3319 - accuracy: 0.5376 - val_loss: 1.3948 - val_accuracy: 0.1250
# Epoch 8/20
# 8/8 [==============================] - 0s 53ms/step - loss: 1.2886 - accuracy: 0.4814 - val_loss: 1.2150 - val_accuracy: 0.9375
# Epoch 9/20
# 8/8 [==============================] - 0s 55ms/step - loss: 1.2179 - accuracy: 0.8388 - val_loss: 1.2264 - val_accuracy: 0.3750
# Epoch 10/20
# 8/8 [==============================] - 0s 53ms/step - loss: 1.0921 - accuracy: 0.6523 - val_loss: 0.9819 - val_accuracy: 0.9688
# Epoch 11/20
# 8/8 [==============================] - 0s 53ms/step - loss: 0.9723 - accuracy: 0.8411 - val_loss: 0.8185 - val_accuracy: 0.8750
# Epoch 12/20
# 8/8 [==============================] - 0s 54ms/step - loss: 0.7334 - accuracy: 0.8711 - val_loss: 0.5308 - val_accuracy: 0.9688
# Epoch 13/20
# 8/8 [==============================] - 0s 53ms/step - loss: 0.4981 - accuracy: 0.9228 - val_loss: 0.3380 - val_accuracy: 0.9688
# Epoch 14/20
# 8/8 [==============================] - 0s 53ms/step - loss: 0.2819 - accuracy: 0.9442 - val_loss: 0.1661 - val_accuracy: 1.0000
# Epoch 15/20
# 8/8 [==============================] - 0s 53ms/step - loss: 0.1477 - accuracy: 0.9860 - val_loss: 0.0511 - val_accuracy: 1.0000
# Epoch 16/20
# 8/8 [==============================] - 0s 54ms/step - loss: 0.0757 - accuracy: 0.9947 - val_loss: 0.0260 - val_accuracy: 1.0000
# Epoch 17/20
# 8/8 [==============================] - 0s 53ms/step - loss: 0.0503 - accuracy: 1.0000 - val_loss: 0.0186 - val_accuracy: 1.0000
# Epoch 18/20
# 8/8 [==============================] - 0s 53ms/step - loss: 0.0221 - accuracy: 1.0000 - val_loss: 0.0090 - val_accuracy: 1.0000
# Epoch 19/20
# 8/8 [==============================] - 0s 53ms/step - loss: 0.0162 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 20/20
# 8/8 [==============================] - 0s 53ms/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.0104 - val_accuracy: 1.0000

# %%
plt.plot(history.history['accuracy'], label = 'accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')

test_loss, test_acc = model.evaluate(X_test,  y_test, verbose=2)

print(test_acc)
# Out:
# 1/1 - 0s - loss: 0.0104 - accuracy: 1.0000
# 1.0
